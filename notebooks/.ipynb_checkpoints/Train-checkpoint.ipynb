# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib
import random 
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
# Helper Functions

def plot_class_distribution (data_frame, groupby_feature,class_name, starting_index=0):
    grouped  = data_frame.groupby([class_name]) 
    values=grouped[groupby_feature].agg(np.size)[starting_index:]  
    labels =  values.index.tolist()  
    y_pos = np.arange(len(labels))
    plt.bar(y_pos, values)
    plt.xticks(y_pos, labels)
    plt.xlabel('Product categories')
    plt.ylabel('Number of Products')
    plt.show()

# %%
inputFile="../data/labeled/labeled_dataV1.csv"
df = pd.read_csv(inputFile)
#df=df[1:500000]

# our categories and their related words
classes=['unisex', 'men', 'women', 'kid', 'baby']
 

labeled_data=df[df['class']!= '-1'].copy()

#encode the classes to their index 
labeled_data['labels']=labeled_data['class'].apply( classes.index)
print(classes)
# Out:
# ['unisex', 'men', 'women', 'kid', 'baby']

# %% [markdown]
# ### Remove unnecessary columns

# %%
#get rid 
#df.drop(labels=['description', 'unisex', 'men', 'women', 'baby', 'kid', 'store_product_brand_domain'], axis=1)
#df.loc[:, ['product_type','full_store_product_url','all_tokens','all_text','all_text_original','primary_price' ]]

# %%
# Helper Functions

def plot_class_distribution (data_frame, groupby_feature,class_name, starting_index=0):
    grouped  = data_frame.groupby([class_name]) 
    values=grouped[groupby_feature].agg(np.size)[starting_index:]  
    labels =  values.index.tolist()  
    y_pos = np.arange(len(labels))
    plt.bar(y_pos, values)
    plt.xticks(y_pos, labels)
    plt.xlabel('Product categories')
    plt.ylabel('Number of Products')
    plt.show()

# %% [markdown]
# # Bag of Words Counts

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def cv(data):
    count_vectorizer = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,2))
    emb = count_vectorizer.fit_transform(data)
    return emb, count_vectorizer


list_corpus = labeled_data["all_text"].tolist()
list_labels = labeled_data["labels"].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, 
                                                    list_labels, test_size=0.2,
                                                     random_state=40)

X_train_counts, count_vectorizer = cv(X_train)
X_test_counts = count_vectorizer.transform(X_test)

#size of our features
X_train_counts.shape
# Out:
# (49033, 153035)

# %% [markdown]
# ## Visualizing the embeddings
# Since visualizing data in large dimensions is hard, let's project it down to 2.

# %%
def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','red', 'yellow', 'green']
        if plot:
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            orange_patch = mpatches.Patch(color='orange', label='Unisex')
            blue_patch = mpatches.Patch(color='blue', label='Men')
            red_patch = mpatches.Patch(color='red', label='Women')
            yellow_patch = mpatches.Patch(color='yellow', label='Kids')
            green_patch = mpatches.Patch(color='black', label='Baby')
            plt.legend(handles=[orange_patch, blue_patch, red_patch,yellow_patch, green_patch], prop={'size': 15})


fig = plt.figure(figsize=(7, 7))          
plot_LSA(X_train_counts, y_train)
plt.show()

# %%
#display(df.head())
#display(labeled_data.head())

print(df.shape)
print(labeled_data.shape)
# Out:
# (500000, 19)
# (61292, 20)

# %% [markdown]
# ## Fitting logistic regression

# %%
clf = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf.fit(X_train_counts, y_train)

y_predicted_counts = clf.predict(X_test_counts)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

def get_metrics(y_test, y_predicted):  
    # true positives / (true positives+false positives)
    precision = precision_score(y_test, y_predicted, pos_label=None,
                                    average='weighted')             
    # true positives / (true positives + false negatives)
    recall = recall_score(y_test, y_predicted, pos_label=None,
                              average='weighted')
    
    # harmonic mean of precision and recall
    f1 = f1_score(y_test, y_predicted, pos_label=None, average='weighted')
    
    # true positives + true negatives/ total
    accuracy = accuracy_score(y_test, y_predicted)
    return accuracy, precision, recall, f1

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.998, precision = 0.998, recall = 0.998, f1 = 0.998

# %%
y_predicted_counts
# Out:
# array([1, 3, 4, ..., 4, 4, 1])

# %% [markdown]
# ## Let's see how confident is our classifier

# %%
allRecords_probabilty=clf.predict_proba(X_test_counts)

allRecords_max_probabilty = []
for i in range(0, allRecords_probabilty.shape[0]):
    probablities=allRecords_probabilty[i]
    prob_index= np.argmax(probablities)
    prob_max= max(probablities)
    allRecords_max_probabilty.append(prob_max)

# %%
fig = plt.figure(figsize=(5, 5)) 
plt.xlabel('Prediction Probability')
plt.ylabel('Number of records')
plt.hist(allRecords_max_probabilty)
plt.show()

# %% [markdown]
# ## Inspection
#  Let's start by looking at the confusion matrix.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.winter):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=20)
    plt.yticks(tick_marks, classes, fontsize=20)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", 
                 color="white" if cm[i, j] < thresh else "black", fontsize=15)
    
    plt.tight_layout()
    plt.ylabel('True label', fontsize=15)
    plt.xlabel('Predicted label', fontsize=15)

    return plt

# %%
cm = confusion_matrix(y_test, y_predicted_counts)
fig = plt.figure(figsize=(7, 7))
plot = plot_confusion_matrix(cm, classes=classes, normalize=False, title='Confusion matrix')
plt.show()
print(cm)
# Out:
# [[ 554    0    0    0    0]
#  [   0 3644    6    5    1]
#  [   0    3 4600    0    0]
#  [   0    2    0 1427    0]
#  [   0    0    2    1 2014]]

# %%
plot_class_distribution (unlabeled_data, 'product_type','class', starting_index=0)
print(unlabeled_data['class'].value_counts())
# Out:
# men       418451
# kid        14134
# baby        4367
# unisex       907
# women        849
# Name: class, dtype: int64

# %% [markdown]
# ## Further inspection
# Let's look at the features our classifier is using to make decisions.

# %%
def get_most_important_features(vectorizer, model, n=5):
    index_to_word = {v:k for k,v in vectorizer.vocabulary_.items()}
    
    # loop for each class
    classes ={}
    for class_index in range(model.coef_.shape[0]):
        word_importances = [(el, index_to_word[i]) for i,el in enumerate(model.coef_[class_index])]
        sorted_coeff = sorted(word_importances, key = lambda x : x[0], reverse=True)
        tops = sorted(sorted_coeff[:n], key = lambda x : x[0])
        bottom = sorted_coeff[-n:]
        classes[class_index] = {
            'tops':tops,
            'bottom':bottom
        }
    return classes

importance = get_most_important_features(count_vectorizer, clf, 15)

# %%
def plot_important_words( top_words, top_scores, label, position):

    y_pos = np.arange(len(top_words))
    plt.subplot(position)
    plt.barh(y_pos,top_scores, align='center', alpha=0.5)
    plt.title(label, fontsize=20)
    plt.yticks(y_pos, top_words, fontsize=14)




top_scores_unisex = [a[0] for a in importance[0]['tops']]
top_words_unisex = [a[1] for a in importance[0]['tops']]

top_scores_men = [a[0] for a in importance[1]['tops']]
top_words_men = [a[1] for a in importance[1]['tops']]

top_scores_women = [a[0] for a in importance[2]['tops']]
top_words_women = [a[1] for a in importance[2]['tops']]

top_scores_kid = [a[0] for a in importance[3]['tops']]
top_words_kid = [a[1] for a in importance[3]['tops']]

top_scores_baby = [a[0] for a in importance[4]['tops']]
top_words_baby = [a[1] for a in importance[4]['tops']]

#plot_important_words(top_scores_unisex, top_words_unisex, top_scores_men, top_words_men, "Most important words")


unisex_pairs = [(a,b) for a,b in zip(top_words_unisex, top_scores_unisex)]
men_pairs = [(a,b) for a,b in zip(top_words_men, top_scores_men)]
unisex_pairs = [(a,b) for a,b in zip(top_words_unisex, top_scores_unisex)]
men_pairs = [(a,b) for a,b in zip(top_words_men, top_scores_men)]

fig = plt.figure(figsize=(25, 25))  
plot_important_words(top_words_unisex, top_scores_unisex, "Unisex", 321)   
plot_important_words(top_words_men, top_scores_men, "Men", 322)
plot_important_words(top_words_women, top_scores_women, "Women", 323)
plot_important_words(top_words_kid, top_scores_kid, "Kids", 324)
plot_important_words(top_words_baby, top_scores_baby, "Baby", 325)

plt.subplots_adjust(wspace=0.4, hspace = 0.6)
plt.suptitle("Important Keywords", fontsize=18)
plt.xlabel('Importance')
plt.show()

# %%
#from pivottablejs import pivot_ui
#pivot_ui(labeled_data )

# %% [markdown]
# ## let's see how our CLF model performs on unseen data
# We can use the prediction probability as a performance metric

# %%
unlabeled_data= df[df['class'] == '-1'].copy()

# %%
list_corpus = unlabeled_data["all_text"].tolist()
#list_labels = unlabeled_data["labels"].tolist()
X_test_counts = count_vectorizer.transform(list_corpus)
y_test_counts = clf.predict(X_test_counts)

# add prediction to the unlabeled_data dataframe
unlabeled_data['labels']=y_test_counts
unlabeled_data['class']=unlabeled_data['labels'].apply( classes.__getitem__)
print(X_test_counts.shape)
# Out:
# (438708, 153035)

# %%
allRecords_probabilty=clf.predict_proba(X_test_counts)

allRecords_max_probabilty = []
for i in range(0, allRecords_probabilty.shape[0]):
    probablities=allRecords_probabilty[i]
    prob_index= np.argmax(probablities)
    prob_max= max(probablities)
    allRecords_max_probabilty.append(prob_max)

# add prediction probability to the unlabeled_data dataframe
unlabeled_data['probability']= allRecords_max_probabilty

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5, 5)) 
plt.xlabel('Prediction Probability')
plt.ylabel('Number of records')
plt.hist(allRecords_max_probabilty)
plt.show()

# %%
confidence_threshold=0.8
high_confidence=unlabeled_data[unlabeled_data['probability']>= confidence_threshold] 
high_confidence_size=high_confidence.shape[0]
low_confidence_size=unlabeled_data.shape[0]-  high_confidence_size
print( "Number of records predicted with high confidence is {} out of {}".format( high_confidence_size, unlabeled_data.shape[0]))
print( "Number of records predicted with low confidence is {} out of {}".format( low_confidence_size, unlabeled_data.shape[0]))
# Out:
# Number of records predicted with high confidence is 260443 out of 438708
# Number of records predicted with low confidence is 178265 out of 438708

# %% [markdown]
# ## Let's select 40 random records and check their prediction manually

# %%
unisex_products=unlabeled_data[unlabeled_data['class']== 'unisex'] 
unisex_products
# Out:
#         Unnamed: 0            product_type               vendor_name  \
# 8736          8736       ['bag', 'wallet']                   ['187']
# 8737          8737         ['wristguards']  ['187', 'killer', 'pad']
# 8740          8740         ['knee', 'pad']                   ['187']
# 8741          8741  ['protective', 'gear']  ['187', 'killer', 'pad']
# 8742          8742        ['elbow', 'pad']                   ['187']
# ...            ...                     ...                       ...
# 479952      479952             ['scooter']         ['chilli', 'pro']
# 486797      486797              ['hoodie']               ['juniper']
# 486809      486809              ['tshirt']               ['juniper']
# 486820      486820              ['hoodie']   ['juniper', 'clothing']
# 486823      486823              ['hoodie']               ['juniper']
#
#                                                     title  \
# 8736    ['187', 'duffle', 'bag', 'war', 'machine', 'bl...
# 8737                   ['187', 'derby', 'wrist', 'guard']
# 8740    ['187', 'knee', 'pad', 'fly', 'knee', 'red', '...
# 8741                       ['187', 'elbow', 'pad', 'pro']
# 8742     ['187', 'killer', 'pad', 'pro', 'elbow', 'grey']
# ...                                                   ...
# 479952  ['chilli', 'pro', 'turbo', 'black', 'black', '...
# 486797                     ['mountain', 'logo', 'hoodie']
# 486809                                     ['come', 'go']
# 486820                               ['deadly', 'hoodie']
# 486823                     ['mountain', 'tree', 'hoodie']
#
#                               store_domain store_product_brand_domain  \
# 8736             ['skateconnection', 'au']          ['187killerpads']
# 8737                          ['daklinic']          ['187killerpads']
# 8740            ['skatealley', 'co', 'uk']          ['187killerpads']
# 8741                  ['shinertown', 'au']          ['187killerpads']
# 8742    ['mommatruckerskates', 'co', 'uk']          ['187killerpads']
# ...                                    ...                        ...
# 479952                      ['locoskates']   ['chilli', 'proscooter']
# 486797           ['juniperclothing', 'ca']  ['juniperclothing', 'ca']
# 486809           ['juniperclothing', 'ca']  ['juniperclothing', 'ca']
# 486820           ['juniperclothing', 'ca']  ['juniperclothing', 'ca']
# 486823           ['juniperclothing', 'ca']  ['juniperclothing', 'ca']
#
#        description primary_price  \
# 8736            []         74.95
# 8737            []         49.95
# 8740            []         39.99
# 8741            []         100.0
# 8742            []         44.99
# ...            ...           ...
# 479952          []         16.67
# 486797          []         29.99
# 486809          []         31.99
# 486820          []         49.99
# 486823          []         29.99
#
#                                    full_store_product_url  \
# 8736    https://skateconnection.com.au/products/187duf...
# 8737        https://daklinic.com/products/187-derby-wrist
# 8740    https://skatealley.co.uk/products/187-knee-pad...
# 8741    https://shinertown.com.au/products/187-pro-elb...
# 8742    https://mommatruckerskates.co.uk/products/187-...
# ...                                                   ...
# 479952  https://locoskates.com/products/chilli-pro-tur...
# 486797  https://juniperclothing.ca/products/bold-mount...
# 486809  https://juniperclothing.ca/products/come-on-we...
# 486820  https://juniperclothing.ca/products/deadly-hoodie
# 486823  https://juniperclothing.ca/products/mountain-a...
#
#                                         all_text_original  ...  \
# 8736    Bags and Wallets 187 187 Duffle Bag War Machin...  ...
# 8737    WRISTGUARDS 187 Killer Pads 187 Derby Wrist Gu...  ...
# 8740    Knee Pads 187 187 Knee Pads Fly Knee - Red/Whi...  ...
# 8741    Protective Gear 187 Killer Pads 187 Elbow Pads...  ...
# 8742    Elbow Pads 187 187 Killer Pads - Pro Elbow Gre...  ...
# ...                                                   ...  ...
# 479952  Scooter Chilli Pro Chilli Pro Turbo Black / Bl...  ...
# 486797  Hoodie Juniper Mountain Logo Hoodie juniperclo...  ...
# 486809  tshirt Juniper Come on we goes juniperclothing...  ...
# 486820  Hoodie Juniper Clothing Deadly Hoodie juniperc...  ...
# 486823  Hoodie Juniper Mountain and Tree Hoodie junipe...  ...
#
#                                                all_tokens unisex  men  women  \
# 8736    ['bag', 'wallet', '187', '187', 'duffle', 'bag...      0    0      0
# 8737    ['wristguards', '187', 'killer', 'pad', '187',...      0    0      0
# 8740    ['knee', 'pad', '187', '187', 'knee', 'pad', '...      0    0      0
# 8741    ['protective', 'gear', '187', 'killer', 'pad',...      0    0      0
# 8742    ['elbow', 'pad', '187', '187', 'killer', 'pad'...      0    0      0
# ...                                                   ...    ...  ...    ...
# 479952  ['scooter', 'chilli', 'pro', 'chilli', 'pro', ...      0    0      0
# 486797  ['hoodie', 'juniper', 'mountain', 'logo', 'hoo...      0    0      0
# 486809  ['tshirt', 'juniper', 'come', 'go', 'junipercl...      0    0      0
# 486820  ['hoodie', 'juniper', 'clothing', 'deadly', 'h...      0    0      0
# 486823  ['hoodie', 'juniper', 'mountain', 'tree', 'hoo...      0    0      0
#
#         baby  kid   class                                           all_text  \
# 8736       0    0  unisex  bag wallet 187 187 duffle bag war machine blac...
# 8737       0    0  unisex  wristguards 187 killer pad 187 derby wrist gua...
# 8740       0    0  unisex  knee pad 187 187 knee pad fly knee red white b...
# 8741       0    0  unisex  protective gear 187 killer pad 187 elbow pad p...
# 8742       0    0  unisex  elbow pad 187 187 killer pad pro elbow grey mo...
# ...      ...  ...     ...                                                ...
# 479952     0    0  unisex  scooter chilli pro chilli pro turbo black blac...
# 486797     0    0  unisex  hoodie juniper mountain logo hoodie juniperclo...
# 486809     0    0  unisex  tshirt juniper come go juniperclothing ca juni...
# 486820     0    0  unisex  hoodie juniper clothing deadly hoodie juniperc...
# 486823     0    0  unisex  hoodie juniper mountain tree hoodie juniperclo...
#
#        labels  probability
# 8736        0     0.896867
# 8737        0     0.996880
# 8740        0     0.998578
# 8741        0     0.998099
# 8742        0     0.999802
# ...       ...          ...
# 479952      0     0.752198
# 486797      0     0.484916
# 486809      0     0.296140
# 486820      0     0.344465
# 486823      0     0.413440
#
# [907 rows x 21 columns]

# %%
random_records=random.sample(unlabeled_data.index.to_list(), k=20) 
test=unlabeled_data.loc[random_records, ['class','labels','product_type','full_store_product_url' ,'all_text_original']]
display(test)
test.to_csv("../data/validate/test_random_unseen_data_LogisticReg.csv", index=True)
# Out:
#        class  labels                          product_type  \
# 301021   men       1                            ['jogger']
# 369577   men       1                            ['jacket']
# 173680   men       1                            ['jumper']
# 21174    men       1                             ['wheel']
# 26281    men       1                             ['flake']
# 320191   men       1                     ['top', 'bikini']
# 45215    men       1                             ['cooky']
# 30902    men       1                               ['mug']
# 140086   men       1                                    []
# 354011   men       1                                    []
# 471673   men       1                                    []
# 126212   men       1                              ['bowl']
# 360749   men       1                                 ['r']
# 388126   men       1                            ['wallet']
# 224695   men       1             ['ivy', 'league', 'clip']
# 233212   men       1                  ['pendant', 'charm']
# 317646   men       1  ['premium', 'knit', 'crib', 'sheet']
# 498875   men       1                               ['eye']
# 443395   men       1                            ['poster']
# 460609   men       1                                    []
#
#                                    full_store_product_url  \
# 301021    https://khazanay.pk/products/brooks-gts-s-49488
# 369577  https://brotherswestand.com/products/yarmouth-...
# 173680  https://heysara.com/products/sass-sunday-morni...
# 21174   https://hardparkpro.com/products/vorsteiner-v-...
# 26281   https://lemminglacquer.com/products/cosmic-dip...
# 320191  https://zueswimwear.com/products/top-balconett...
# 45215   https://frankandsal.com/products/mulino-bianco...
# 30902   https://felizland.com/products/cup-of-love-con...
# 140086  https://ellany.com/products/ellany-windbreaker...
# 354011         https://bapsaccessories.com/products/seven
# 471673  https://sugarqueenfashion.com/products/striped...
# 126212   https://stinsonstudios.ca/products/round-bowl-us
# 360749            https://meba.is/products/kenneth-cole-9
# 388126  https://kronkron.com/products/belgravia-long-w...
# 224695  https://theweekendsociety.com/products/varsity...
# 233212  https://jewelryisme.com/products/10k-yellow-go...
# 317646  https://copperpearl.com/products/premium-fitte...
# 498875  https://flyartist.com/products/3d-holographic-...
# 443395        https://typealive.de/products/print-mon-day
# 460609  https://maltessa.es/products/collar-multicharm...
#
#                                         all_text_original
# 301021  Joggers Brooks Brooks GTS khazanay.pk brooksru...
# 369577  Jackets Yarmouth Oilskins Yarmouth Oilskins Dr...
# 173680  Jumper SASS Sass Sunday Morning Jumper in Grey...
# 21174   Wheels Vorsteiner Vorsteiner V-FF 112 Wheel (1...
# 26281   Flakes Lemming Lacquer Cosmic Dipshits lemming...
# 320191  Top Bikini Zue Swimwear TOP Balconette Embera ...
# 45215   Cookies Frank and Sal  Mulino Bianco Settembri...
# 30902   Mug Felizland Cup Of Love - Heart Mug felizlan...
# 140086  nan Ellany Equestrian Ellany Windbreaker - Nav...
# 354011  nan B.A.P.S. Accessories Seven bapsaccessories...
# 471673  nan Sugar Queen Fashion  Striped Out Jumpsuit ...
# 126212  Bowl Stinson Studios - US Round Ambrosia Maple...
# 360749  Úr Kenneth Cole Kenneth Cole meba.is kennethco...
# 388126  Wallet Vivienne Westwood - Bags & Wallets Belg...
# 224695  IVY LEAGUE CLIP The American Weekend Society V...
# 233212  Pendant/Charm Jewelry Is Me 10k Yellow Gold Es...
# 317646  Premium Knit Crib Sheet Copper Pearl Premium K...
# 498875  Eyes Hareline 3D Adhesive Holographic Fish Eye...
# 443395  Poster typealive Print / Mon Day typealive.de ...
# 460609  nan Maltessa-Profesionales Collar Multicharms ...

# %%
plot_class_distribution (unlabeled_data, 'product_type','class', starting_index=0)
print(unlabeled_data['class'].value_counts())
# Out:
# men       418451
# kid        14134
# baby        4367
# unisex       907
# women        849
# Name: class, dtype: int64

# %%
df[df['class']==-1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_type, vendor_name, title, store_domain, store_product_brand_domain, description, primary_price, full_store_product_url, all_text_original, vendor_name_original, all_tokens, unisex, men, women, baby, kid, class, all_text]
# Index: []
